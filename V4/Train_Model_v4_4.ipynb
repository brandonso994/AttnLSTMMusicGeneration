# %% [markdown]
# <a href="https://colab.research.google.com/github/brandonso994/AttnLSTMMusicGeneration/blob/main/V4/Train_Model_v4_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras_self_attention
# Out:
# Collecting keras_self_attention
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras_self_attention) (1.22.4)
# Building wheels for collected packages: keras_self_attention
#   Building wheel for keras_self_attention (setup.py) ... done
#   Created wheel for keras_self_attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18895 sha256=8724067784cb3a0cda2e0e2f5ce4f2e8858160b628df9feba5bca8973d81c8f9
#   Stored in directory: /root/.cache/pip/wheels/b8/f7/24/607b483144fb9c47b4ba2c5fba6b68e54aeee2d5bf6c05302e
# Successfully built keras_self_attention
# Installing collected packages: keras_self_attention
# Successfully installed keras_self_attention-0.51.0

# %%
from music21 import converter, instrument, note, chord, stream, volume
from fractions import Fraction
import matplotlib.pyplot as plt
import glob
import numpy as np
import nltk
import pandas as pd
import pickle
from keras.models import Sequential, Model
from keras.layers import LSTM, Dropout, Dense, Activation, Bidirectional, BatchNormalization, Input, Embedding, Concatenate, Flatten
from keras.utils import np_utils
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.metrics import CategoricalAccuracy
import tensorflow as tf
from keras import backend as K
from keras_self_attention import SeqSelfAttention

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Class function to stop training of loss goes below 0.2 to prevent overtraining
class EarlyStopOnLossCallback(EarlyStopping):
    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('loss')
        if current_loss is not None and current_loss < 0.4:
            self.stopped_epoch = epoch
            self.model.stop_training = True
            print("Training stopped. Loss below threshold.")

# %%
# Function to flatten array into 1d array
def flatten(array):
  new_array = [item for array in array for item in array]
  return new_array

# Create window sequences to feed into model for training
def sequence(notes, note_set_len, sequence_length):

  # Create Note Set
  note_values = sorted(set(note for note in notes))

  # Dictionary to encode each feature to an integer
  note_encode = dict((note, num) for num, note in enumerate(note_values))

  network_input_note = []
  note_output = []

  # Create moving window sequences, with target output being i + sequence length index
  for i in range (len(notes) - sequence_length):
    sequence_in_note = notes[i:i + sequence_length]
    sequence_out = notes[i + sequence_length]
    network_input_note.append([note_encode[note] for note in sequence_in_note])
    note_output.append(note_encode[sequence_out])

  # Reshape input suitable for LSTM input
  n_patterns = len(network_input_note)
  network_input_note = np.reshape(network_input_note, (n_patterns, sequence_length, 1))

  # Normalize the input
  network_input_note = network_input_note / float(note_set_len)

  # One hot encode output
  note_output = np_utils.to_categorical(note_output)

  return network_input_note, note_output

#Create the model
def create_model(network_input_note, note_set_len):

    model = Sequential()

    # Note input
    model.add(Bidirectional(LSTM(1024,return_sequences=True),input_shape=(network_input_note.shape[1], network_input_note.shape[2])))
    model.add(SeqSelfAttention(attention_activation='sigmoid'))
    model.add(Dropout(0.3))
    model.add(LSTM(1024,return_sequences=False))
    model.add(Dropout(0.3))

    model.add(Dense(note_set_len, activation='softmax', name='note'))

    return model

# Train the Model. Be sure to change all paths to the folder locations you will be using
def train_model(notes, version_num):

  # Window Size Hyperparameter
  sequence_length = 60

  # Flatten arrays
  flatten_notes = flatten(notes)

  # Feature Vocabulary Size
  note_set_len = len(set(flatten_notes))

  # Create sequence windows and output variable to feed into model
  note_input, note_output = sequence(flatten_notes, note_set_len, sequence_length)

  # Initialize Model
  model = create_model(note_input, note_set_len)

  # Compile using Categorical Crossentropy and Categorical Accuracy as metrics, optmizer Adam
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

  # Early stop when accuracy drops below 0.2 loss. Model saves weights with the greatest pitch categorical accuracy.
  callbacks = [
        EarlyStopOnLossCallback(monitor='loss'),
        ModelCheckpoint('/content/drive/My Drive/MRP/Model/model_weights_' + version_num + '_checkpoints.h5', monitor='categorical_accuracy', save_freq="epoch", save_best_only=True, mode='max', save_weights_only = True)
  ]

  # Fit model, 100 epochs, batch size 64
  history = model.fit(note_input, note_output,
    epochs=100, batch_size=64, callbacks=callbacks)

  # Save Stats
  model.save_weights('/content/drive/My Drive/MRP/Model/model_weights_' + version_num + '.h5')
  model.save('/content/drive/My Drive/MRP/Model/model_' + version_num + '.h5')

  with open('/content/drive/My Drive/MRP/Model/history_ ' + version_num + '.pkl','wb') as f:
    pickle.dump(history.history, f)

  with open('history_'+version_num + '.pkl','wb') as f:
    pickle.dump(history.history, f)

  return history, model

# %%
# Load Pickle Files
with open('simple_notes_offsets.pkl', 'rb') as f:
  notes = pickle.load(f)

# Check Pickle Contents
note_set_len = len(set(flatten(notes)))

print(len(notes))
print(len(flatten(notes)))
print(note_set_len)
# Out:
# 162
# 195674
# 10637

# %%
history, model = train_model(notes, 'v4_4')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/initializers/initializers.py:120: UserWarning: The initializer GlorotNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Epoch 1/100
# 3057/3057 [==============================] - 90s 25ms/step - loss: 7.4384 - categorical_accuracy: 0.0168
# Epoch 2/100
# 3057/3057 [==============================] - 78s 25ms/step - loss: 7.1981 - categorical_accuracy: 0.0197
# Epoch 3/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 7.0730 - categorical_accuracy: 0.0207
# Epoch 4/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 6.9650 - categorical_accuracy: 0.0219
# Epoch 5/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 6.8501 - categorical_accuracy: 0.0231
# Epoch 6/100
# 3057/3057 [==============================] - 78s 25ms/step - loss: 6.6947 - categorical_accuracy: 0.0279
# Epoch 7/100
# 3057/3057 [==============================] - 78s 25ms/step - loss: 6.4717 - categorical_accuracy: 0.0349
# Epoch 8/100
# 3057/3057 [==============================] - 78s 25ms/step - loss: 6.1705 - categorical_accuracy: 0.0475
# Epoch 9/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 5.7939 - categorical_accuracy: 0.0667
# Epoch 10/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 5.3809 - categorical_accuracy: 0.0955
# Epoch 11/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 4.9453 - categorical_accuracy: 0.1334
# Epoch 12/100
# 3057/3057 [==============================] - 78s 26ms/step - loss: 4.4951 - categorical_accuracy: 0.1795
# Epoch 13/100
# 3057/3057 [==============================] - 78s 25ms/step - loss: 4.0535 - categorical_accuracy: 0.2324
# Epoch 14/100
# 3057/3057 [==============================] - 78s 25ms/step - loss: 3.6610 - categorical_accuracy: 0.2838
# Epoch 15/100
# 3057/3057 [==============================] - 78s 26ms/step - loss: 3.2761 - categorical_accuracy: 0.3367
# Epoch 16/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 2.9454 - categorical_accuracy: 0.3856
# Epoch 17/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 2.6382 - categorical_accuracy: 0.4361
# Epoch 18/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 2.3658 - categorical_accuracy: 0.4817
# Epoch 19/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 2.1211 - categorical_accuracy: 0.5242
# Epoch 20/100
# 3057/3057 [==============================] - 78s 25ms/step - loss: 1.9199 - categorical_accuracy: 0.5591
# Epoch 21/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 1.7202 - categorical_accuracy: 0.5960
# Epoch 22/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 1.5654 - categorical_accuracy: 0.6252
# Epoch 23/100
# 3057/3057 [==============================] - 78s 26ms/step - loss: 1.4130 - categorical_accuracy: 0.6561
# Epoch 24/100
# 3057/3057 [==============================] - 78s 25ms/step - loss: 1.2849 - categorical_accuracy: 0.6814
# Epoch 25/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 1.1652 - categorical_accuracy: 0.7064
# Epoch 26/100
# 3057/3057 [==============================] - 78s 25ms/step - loss: 1.0672 - categorical_accuracy: 0.7265
# Epoch 27/100
# 3057/3057 [==============================] - 78s 26ms/step - loss: 0.9866 - categorical_accuracy: 0.7423
# Epoch 28/100
# 3057/3057 [==============================] - 78s 26ms/step - loss: 0.9026 - categorical_accuracy: 0.7625
# Epoch 29/100
# 3057/3057 [==============================] - 78s 26ms/step - loss: 0.8305 - categorical_accuracy: 0.7798
# Epoch 30/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 0.7790 - categorical_accuracy: 0.7899
# Epoch 31/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 0.7167 - categorical_accuracy: 0.8054
# Epoch 32/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 0.6752 - categorical_accuracy: 0.8158
# Epoch 33/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 0.6317 - categorical_accuracy: 0.8258
# Epoch 34/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 0.5974 - categorical_accuracy: 0.8336
# Epoch 35/100
# 3057/3057 [==============================] - 78s 25ms/step - loss: 0.5579 - categorical_accuracy: 0.8445
# Epoch 36/100
# 3057/3057 [==============================] - 78s 25ms/step - loss: 0.5242 - categorical_accuracy: 0.8523
# Epoch 37/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 0.5101 - categorical_accuracy: 0.8560
# Epoch 38/100
# 3057/3057 [==============================] - 78s 25ms/step - loss: 0.4800 - categorical_accuracy: 0.8636
# Epoch 39/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 0.4639 - categorical_accuracy: 0.8679
# Epoch 40/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 0.4347 - categorical_accuracy: 0.8751
# Epoch 41/100
# 3057/3057 [==============================] - 78s 25ms/step - loss: 0.4230 - categorical_accuracy: 0.8799
# Epoch 42/100
# 3057/3057 [==============================] - 77s 25ms/step - loss: 0.4054 - categorical_accuracy: 0.8830
# Epoch 43/100
# 3055/3057 [============================>.] - ETA: 0s - loss: 0.3892 - categorical_accuracy: 0.8881Training stopped. Loss below threshold.
# 3057/3057 [==============================] - 77s 25ms/step - loss: 0.3893 - categorical_accuracy: 0.8880

# %%
print(model.summary())
print(history.history.keys())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 60, 2048)         8404992
#  l)
#
#  seq_self_attention (SeqSelf  (None, 60, 2048)         131137
#  Attention)
#
#  dropout (Dropout)           (None, 60, 2048)          0
#
#  lstm_1 (LSTM)               (None, 1024)              12587008
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  note (Dense)                (None, 10637)             10902925
#
# =================================================================
# Total params: 32,026,062
# Trainable params: 32,026,062
# Non-trainable params: 0
# _________________________________________________________________
# None
# dict_keys(['loss', 'categorical_accuracy'])

# %%
plt.plot(history.history['categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical accuracy')
plt.xlabel('epoch')
plt.legend(['categorical_accuracy'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss'], loc='upper left')
plt.show()
